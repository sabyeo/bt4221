# %%
import pandas as pd
import os

# %%
data_all_restaurants_section0 = pd.DataFrame()
count = 0
for file in os.listdir('restaurant-data/section1'):
    if '.csv' in file:
        data = pd.read_csv('restaurant-data/section1/'+ file, index_col=0)
        # check if there are more than 20 reviews
        if (len(data) > 20): 
            count += 1
            data_all_restaurants_section0 = data_all_restaurants_section0.append(data)
# Out:
# /var/folders/74/n55gd6gs38n5wj2k6hwrc_yc0000gn/T/ipykernel_83326/625889441.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_all_restaurants_section0 = data_all_restaurants_section0.append(data)
# /var/folders/74/n55gd6gs38n5wj2k6hwrc_yc0000gn/T/ipykernel_83326/625889441.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_all_restaurants_section0 = data_all_restaurants_section0.append(data)
# /var/folders/74/n55gd6gs38n5wj2k6hwrc_yc0000gn/T/ipykernel_83326/625889441.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_all_restaurants_section0 = data_all_restaurants_section0.append(data)
# ...

# %%
count
# Out:
# 182

# %%
data_all_restaurants_section0.to_csv('restaurant-data/compiled_section1_reviews.csv')
